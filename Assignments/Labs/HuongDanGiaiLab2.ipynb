# %% [markdown]
# **Install PyDrive**
# The first step is to install PyDrive

# %% [markdown]
# **Authenticate**
# The second step is to authenticate and create a PyDrive client

# %% [markdown]
# **Load the CSV**
# For the sixth step, tell your notebook now the name of the CSV file you want to load into memory.

# %% [markdown]
# **Showing the Results**

# %%
import pandas as pd
dftuyensinh = pd.read_csv('processed_dulieuxettuyendaihoc.csv')
dftuyensinh.head()
# Out:
#    STT   T1   L1   H1   S1   V1   X1   D1   N1   T2  ...  TBM1  TBM2  TBM3  \
# 0    1  7.2  7.3  6.3  7.3  7.0  7.9  7.3  5.5  8.4  ...  7.00  7.54  7.01
# 1    2  5.4  3.9  3.9  4.0  5.4  5.4  5.3  2.8  6.3  ...  4.69  5.47  5.07
# 2    3  5.6  6.8  7.2  7.5  4.3  7.4  5.8  3.2  5.0  ...  5.77  5.38  6.04
# 3    4  6.6  6.4  5.3  6.9  5.4  7.3  6.4  5.8  5.1  ...  6.21  5.20  6.88
# 4    5  6.0  5.0  6.0  7.3  6.5  7.7  7.9  6.1  5.4  ...  6.50  6.36  6.99
#
#    XL1  XL2  XL3  US_TBM1  US_TBM2  US_TBM3  KQXT
# 0    K    K    K    2.800    3.016    2.804   0.0
# 1    Y   TB   TB    1.876    2.188    2.028   0.0
# 2   TB   TB   TB    2.308    2.152    2.416   1.0
# 3   TB   TB    K    2.484    2.080    2.752   0.0
# 4    K   TB    K    2.600    2.544    2.796   0.0
#
# [5 rows x 66 columns]

# %% [markdown]
# # Phan 1
# 1. Hãy sắp xếp dữ liệu điểm DH1 theo thứ tự tăng dần

# %%
dftuyensinh.sort_values(by='DH1')
# Out:
#     STT   T1   L1   H1   S1   V1  ...  XL2  XL6  US_TBM1  US_TBM2  US_TBM6  KQXT
# 53   54  4.9  5.9  6.2  5.6  5.9  ...   TB   TB    2.276    2.504    2.408   0.0
# 43   44  6.6  7.2  5.9  6.9  7.6  ...    K    K    2.820    2.644    2.708   0.0
# 72   73  5.5  6.6  7.2  7.6  5.5  ...   TB   TB    2.480    2.352    2.488   0.0
# 5     6  9.3  7.6  7.9  8.6  7.0  ...    G    K    3.184    3.416    2.952   0.0
# 87   88  7.3  4.3  5.3  5.8  4.9  ...   TB   TB    2.176    2.312    2.592   0.0
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...      ...      ...      ...   ...
# 84   85  8.4  7.4  6.0  7.8  6.3  ...    K    K    2.892    3.108    3.032   1.0
# 11   12  7.9  7.0  9.1  8.6  6.1  ...    K    K    2.972    3.088    2.996   1.0
# 23   24  5.3  6.3  5.7  6.9  5.9  ...   TB    K    2.420    2.528    2.684   1.0
# 24   25  2.4  4.1  3.6  5.5  5.9  ...    Y   TB    1.780    1.952    2.164   0.0
# 97   98  8.8  5.5  7.4  7.7  6.2  ...    K    K    2.820    3.136    3.068   1.0
#
# ...

# %% [markdown]
# 2. Hãy sắp xếp dữ liệu điểm DH2 tăng dần theo nhóm giới tính

# %%
dftuyensinh.sort_values(by=['GT','DH1'])
# Out:
#     STT   T1   L1   H1   S1   V1  ...  XL2  XL6  US_TBM1  US_TBM2  US_TBM6  KQXT
# 43   44  6.6  7.2  5.9  6.9  7.6  ...    K    K    2.820    2.644    2.708   0.0
# 83   84  5.9  5.7  7.1  6.7  6.5  ...    K    K    2.588    2.844    2.988   0.0
# 12   13  7.3  6.3  8.7  7.7  6.6  ...    K    K    2.976    2.728    2.984   0.0
# 45   46  6.9  5.3  7.1  5.7  7.0  ...   TB    K    2.676    2.516    2.632   0.0
# 50   51  5.5  7.1  6.1  5.8  6.2  ...   TB    K    2.508    2.540    2.872   0.0
# ..  ...  ...  ...  ...  ...  ...  ...  ...  ...      ...      ...      ...   ...
# 90   91  8.1  7.7  9.1  8.5  6.1  ...    G    G    3.136    3.308    3.316   1.0
# 84   85  8.4  7.4  6.0  7.8  6.3  ...    K    K    2.892    3.108    3.032   1.0
# 11   12  7.9  7.0  9.1  8.6  6.1  ...    K    K    2.972    3.088    2.996   1.0
# 23   24  5.3  6.3  5.7  6.9  5.9  ...   TB    K    2.420    2.528    2.684   1.0
# 97   98  8.8  5.5  7.4  7.7  6.2  ...    K    K    2.820    3.136    3.068   1.0
#
# ...

# %% [markdown]
# 3. Hãy tạo pivot-table để thống kê các giá trị count, sum, mean, median, min, max, sdt, Q1, Q2 và Q3 của DH1 theo KT

# %%
def get_mean(scores):
    return sum(scores)/len(scores)

# %%
# get the mean score for each subject
result = dftuyensinh['DH1'].sum()
print("\nThe result of applying the function on the dataframe:\n")
print(result)
# Out:
# The result of applying the function on the dataframe:
#
# 374.0

# %%
def Q1(g):
  return np.percentile(g,25)

# %%
def Q2(g):
  return np.percentile(g,50)

# %%
def Q3(g):
  return np.percentile(g,75)

# %%
def std(g):
  return np.std(g)

# %%
pd.pivot_table(data=dftuyensinh, index='KT', values='DH1', aggfunc=['sum','mean','median','min','max', std, Q1, Q2, Q3])
# Out:
#        sum      mean median   min   max       std      Q1    Q2     Q3
#        DH1       DH1    DH1   DH1   DH1       DH1     DH1   DH1    DH1
# KT
# A   163.50  3.336735   3.25  1.00  6.50  1.261226  2.2500  3.25  4.250
# A1   17.50  2.916667   3.00  2.00  4.25  0.786165  2.1875  3.00  3.250
# B    29.50  3.277778   3.50  1.75  4.50  0.776785  3.2500  3.50  3.750
# C    79.25  5.660714   5.25  4.75  7.00  0.782665  5.0625  5.25  6.375
# D1   84.25  3.829545   3.75  1.25  6.75  1.338644  3.0000  3.75  4.875

# %%
pd.pivot_table(data=dftuyensinh, index=['KT','KV'], values='DH1', aggfunc=['sum','mean','median','min','max', std, Q1, Q2, Q3])
# Out:
#           sum      mean median   min   max       std      Q1     Q2      Q3
#           DH1       DH1    DH1   DH1   DH1       DH1     DH1    DH1     DH1
# KT KV
# A  1    93.75  3.232759  3.250  1.00  6.50  1.345380  2.0000  3.250  4.2500
#    2    31.75  3.527778  3.500  2.00  6.25  1.346005  2.2500  3.500  4.2500
#    2NT  38.00  3.454545  3.500  2.00  4.75  0.871377  2.8750  3.500  4.1250
# A1 1     4.75  2.375000  2.375  2.00  2.75  0.375000  2.1875  2.375  2.5625
#    2NT  12.75  3.187500  3.250  2.00  4.25  0.797947  2.9375  3.250  3.5000
# B  1    25.75  3.218750  3.375  1.75  4.50  0.804650  3.0000  3.375  3.5625
#    2NT   3.75  3.750000  3.750  3.75  3.75  0.000000  3.7500  3.750  3.7500
# C  1    43.50  5.437500  5.250  4.75  7.00  0.681795  5.0000  5.250  5.4375
#    2    11.50  5.750000  5.750  5.00  6.50  0.750000  5.3750  5.750  6.1250
#    2NT  24.25  6.062500  6.000  5.25  7.00  0.817294  5.2500  6.000  6.8125
# ...

# %% [markdown]
# # Phần 2: Trình bày dữ liệu

# %% [markdown]
# 1. Hãy trình bày dữ liệu biến GT

# %%
gt = dftuyensinh.groupby('GT')['GT'].agg('count')

# %%
gt.plot.bar()

# %%
gt.plot.pie()

# %%
gt.plot.area()

# %% [markdown]
# 2. Hãy trình bày dữ liệu lần lượt các biến: US_TBM1, US_TBM2 và US_TBM3

# %%
cau22 = pd.DataFrame (dftuyensinh, columns = ['US_TBM1', 'US_TBM2','US_TBM3'])

# %%
cau22.describe()
# Out:
#           US_TBM1     US_TBM2  US_TBM3
# count  100.000000  100.000000      0.0
# mean     2.434480    2.559600      NaN
# std      0.391203    0.377656      NaN
# min      1.616000    1.768000      NaN
# 25%      2.107000    2.223000      NaN
# 50%      2.480000    2.588000      NaN
# 75%      2.724000    2.893000      NaN
# max      3.232000    3.416000      NaN

# %% [markdown]
# 3. Hãy trình bày dữ liệu biến DT với các học sinh là nam

# %%
cau3 = dftuyensinh[dftuyensinh['GT'] == 'M']
cau3.groupby('DT')['DT'].agg('count')
# Out:
# DT
# 1.0    1
# 6.0    1
# Name: DT, dtype: int64

# %% [markdown]
# 4. Hãy trình bày dữ liệu biến KV với các học sinh là nam thuộc dân tộc Kinh, có điểm thõa mãn điều kiện (DH1 >= 5.0 và DH2 >= 4.0 và DH3 >= 4.0)

# %%
cau4 = dftuyensinh[(dftuyensinh['GT'] == 'M') & (dftuyensinh['DT'] == 1)]
cau4.groupby('DT')['DT'].agg('count')
# Out:
# DT
# 1.0    1
# Name: DT, dtype: int64

# %% [markdown]
# # Phần 3: Trực quan hóa dữ liệu theo nhóm phân loại

# %% [markdown]
# 1. Trực quan dữ liệu học sinh nữ trên các nhóm XL1, XL2, XL3 dạng unstacked

# %%
cau31 = dftuyensinh[dftuyensinh['GT'] == 'F'].groupby(['XL1', 'XL2', 'XL6'])[['GT']].count()

# %%
cau31.unstack()
# Out:
#           GT
# XL6        G     K   TB
# XL1 XL2
# G   G    1.0   NaN  NaN
# K   G    NaN   1.0  NaN
#     K    NaN  20.0  1.0
#     TB   NaN   2.0  NaN
# TB  K    NaN   8.0  1.0
#     TB   NaN   3.0  6.0
# Y   TB   NaN   1.0  3.0
#     Y    NaN   NaN  1.0

# %%
cau31.plot.bar()

# %% [markdown]
# # Phần 4: Trực quan hóa dữ liệu nâng cao

# %% [markdown]
# 1. Vẽ biểu đồ đường Simple cho biến T1

# %%
dftuyensinh.groupby('T1')['T1'].count().plot()

# %% [markdown]
# 2. Hãy tạo biến phân loại (phanlopt1) cho môn toán (T1) như sau:
#
# a. Từ 0 đến dưới 5 = kém (ký hiệu "k")
#
# b. Từ 5 đến dưới 7 = trung bình (ký hiệu "tb")
#
# c. Từ 7 đến dưới 8 = khá (ký hiệu "k")
#
# d. Từ 8 trở lên = giỏi (ký hiệu "g")

# %%
dftuyensinh.loc[(dftuyensinh['T1'] < 5), 'phanlopt1'] = 'kem'
dftuyensinh.loc[(dftuyensinh['T1'] >=5) & (dftuyensinh['T1'] <7), 'phanlopt1'] = 'trungbinh'
dftuyensinh.loc[(dftuyensinh['T1'] >=7) & (dftuyensinh['T1'] <8), 'phanlopt1'] = 'kha'
dftuyensinh.loc[(dftuyensinh['T1'] >= 8), 'phanlopt1'] = 'gioi'

# %%
dftuyensinh.head(5)
# Out:
#    STT   T1   L1   H1   S1   V1  ...  XL6  US_TBM1  US_TBM2  US_TBM6  KQXT  phanlopt1
# 0    1  7.2  7.3  6.3  7.3  7.0  ...    K    2.800    3.016    2.804   0.0        kha
# 1    2  5.4  3.9  3.9  4.0  5.4  ...   TB    1.876    2.188    2.028   0.0  trungbinh
# 2    3  5.6  6.8  7.2  7.5  4.3  ...   TB    2.308    2.152    2.416   1.0  trungbinh
# 3    4  6.6  6.4  5.3  6.9  5.4  ...    K    2.484    2.080    2.752   0.0  trungbinh
# 4    5  6.0  5.0  6.0  7.3  6.5  ...    K    2.600    2.544    2.796   0.0  trungbinh
#
# [5 rows x 67 columns]

# %% [markdown]
# 3. Vẽ biểu đồ đường Multiple Line cho biến T1 được phân loại bởi biến phanlopt1

# %%
dfphanlopt1 = dftuyensinh.groupby(['T1', 'phanlopt1'])[['T1', 'phanlopt1']].count()

# %%
unstackphanlopt1 = dfphanlopt1.unstack()

# %%
unstackphanlopt1.head(10)
# Out:
#             T1                    phanlopt1
# phanlopt1 gioi  kem kha trungbinh      gioi  kem kha trungbinh
# T1
# 2.4        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN
# 2.5        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN
# 2.6        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN
# 2.7        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN
# 2.8        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN
# 3.0        NaN  2.0 NaN       NaN       NaN  2.0 NaN       NaN
# 3.4        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN
# 3.6        NaN  2.0 NaN       NaN       NaN  2.0 NaN       NaN
# 3.7        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN
# 3.9        NaN  1.0 NaN       NaN       NaN  1.0 NaN       NaN

# %%
unstackphanlopt1['phanlopt1'].plot(ylabel='Count')

# %% [markdown]
# 4. Vẽ biểu đồ Drop-line cho biến T1 được phân loại bởi biến phanlopt1

# %%
unstackphanlopt1['phanlopt1'].plot.bar()

# %% [markdown]
# # Phần 5: Mô tả dữ liệu và khảo sát dạng phân phối

# %% [markdown]
# 1. Hãy mô tả và khảo sát phân phối cho biến T1

# %%
import matplotlib.pyplot as plt
plt.boxplot(dftuyensinh['T1'])
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7fd22981abd0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7fd22981ec10>,
# ...
#  'fliers': [<matplotlib.lines.Line2D at 0x7fd229820c50>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7fd229820710>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7fd22981e190>,
#   <matplotlib.lines.Line2D at 0x7fd22981e6d0>]}

# %%
dftuyensinh['T1'].describe()
# Out:
# count    100.000000
# mean       5.946000
# std        1.608338
# min        2.400000
# 25%        5.000000
# 50%        5.850000
# 75%        7.200000
# max        9.300000
# Name: T1, dtype: float64

# %% [markdown]
# Vẽ biểu đồ Histogram biểu thị hình dáng phân phối

# %%
dftuyensinh['T1'].hist(bins=20)

# %% [markdown]
# Kiểm chứng phân phối chuẩn QQ-Plot

# %%
import statsmodels.api as sm
import pylab as py
sm.qqplot(dftuyensinh['T1'], line ='45')
py.show()

# %% [markdown]
# 2. Hãy mô tả và khảo sát phân phối cho biến T1 trên từng nhóm phân lớp (phanlopT1)
#
#
#
# > Boxplots are one of the most common ways to visualize data distributions from multiple groups. In Python, Seaborn potting library makes it easy to make boxplots and similar plots swarmplot and stripplot (link: https://cmdlinetips.com/2019/03/how-to-make-grouped-boxplots-in-python-with-seaborn/)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.boxplot(y='T1', x='phanlopt1', data=dftuyensinh)

# %%
sns.histplot(y='T1', x='phanlopt1', data=dftuyensinh)

# %% [markdown]
# 2. Hãy khảo sát tương quan giữa biến DH1 theo biến T1
#
#
# > Nhận xét giá trị Covariance hoặc Correlation
#
# > Vẽ biểu đồ Scatter thể hiện liên hệ của biến phụ thuộc DH1 theo biến độc lập T1
#
# Tham khảo: https://machinelearningmastery.com/how-to-use-correlation-to-understand-the-relationship-between-variables/

# %%
dh1t1 = dftuyensinh[['DH1', 'T1']]

# %%
sns.pairplot(dh1t1, kind="scatter")
plt.show()

# %% [markdown]
# 2. Hãy khảo sát tương quan giữa biến DH1 theo biến T1 trên từng nhóm khu vực
# (Tham khảo: https://pandas.pydata.org/pandas-docs/version/0.16.0/visualization.html)

# %%
dh1t1phanlop = dftuyensinh[['DH1', 'T1','KV']]

# %%
g = sns.FacetGrid(dh1t1phanlop, col="KV")
g.map(plt.scatter, "DH1", "T1")

# %% [markdown]
# 3. Hãy khảo sát tương quan giữa các biến DH1, DH2, DH3

# %%
dh123 = dftuyensinh[['DH1', 'DH2', 'DH3']]

# %%
sns.pairplot(dh123, kind="scatter")
plt.show()
